# %% [markdown]
# Must run the Import_All.R script to setup Data_ALL.RData before running this file

# %%
import numpy as np
import pandas as pd
import pyreadr

# %%
result = pyreadr.read_r('Data_ALL.RData')
df_crime = result['df_crime']
df_housing = result['df_housing']

# %%
df_crime.head()
# Out:
#     CMPLNT_NUM CMPLNT_FR_DT  CMPLNT_FR_TM CMPLNT_TO_DT  CMPLNT_TO_TM  \
# 0  522575447.0   08/29/2006       46800.0          NaN           NaN
# 1  403507361.0   11/05/2006       39600.0   11/05/2006       63600.0
# 2  631420068.0   09/08/2006       84600.0   09/09/2006          60.0
# 3  995609899.0   12/13/2011       67200.0   12/13/2011       67740.0
# 4  480667624.0   08/14/2009       15600.0          NaN           NaN
#
#    ADDR_PCT_CD      RPT_DT  KY_CD                       OFNS_DESC  PD_CD  ...  \
# 0         43.0  08/30/2006  578.0                   HARRASSMENT 2  638.0  ...
# 1         66.0  11/05/2006  107.0                        BURGLARY  221.0  ...
# 2        106.0  09/09/2006  347.0  INTOXICATED & IMPAIRED DRIVING  905.0  ...
# 3         79.0  12/13/2011  341.0                   PETIT LARCENY  333.0  ...
# 4         30.0  08/14/2009  113.0                         FORGERY  729.0  ...
#
#   SUSP_SEX TRANSIT_DISTRICT   Latitude  Longitude  \
# ...

# %%
df_housing.head()
# Out:
#   borough neighborhood building_class_category tax_class_at_present   block  \
# 0       2     BATHGATE    01  ONE FAMILY HOMES                    1  3035.0
# 1       2     BATHGATE    01  ONE FAMILY HOMES                    1  3046.0
# 2       2     BATHGATE    01  ONE FAMILY HOMES                    1  3046.0
# 3       2     BATHGATE    01  ONE FAMILY HOMES                    1  3048.0
# 4       2     BATHGATE    01  ONE FAMILY HOMES                    1  3048.0
#
#     lot ease_ment building_class_at_present                address  \
# 0   5.0       NaN                        A9    451 EAST 178 STREET
# 1  42.0       NaN                        A1   2069 BATHGATE AVENUE
# 2  42.0       NaN                        A1      2069 BATHGATE AVE
# 3  19.0       NaN                        A5   2186 BATHGATE AVENUE
# 4  28.0       NaN                        A1  540 EAST 182ND STREET
#
#   apartment_number  ...  residential_units  commercial_units  total_units  \
# ...

# %% [markdown]
# Splitting housing data into different sets for testing and training

# %%
X = df_housing.loc[:, df_housing.columns != 'sale_price']
X.head()
# Out:
#   borough neighborhood building_class_category tax_class_at_present   block  \
# 0       2     BATHGATE    01  ONE FAMILY HOMES                    1  3035.0
# 1       2     BATHGATE    01  ONE FAMILY HOMES                    1  3046.0
# 2       2     BATHGATE    01  ONE FAMILY HOMES                    1  3046.0
# 3       2     BATHGATE    01  ONE FAMILY HOMES                    1  3048.0
# 4       2     BATHGATE    01  ONE FAMILY HOMES                    1  3048.0
#
#     lot ease_ment building_class_at_present                address  \
# 0   5.0       NaN                        A9    451 EAST 178 STREET
# 1  42.0       NaN                        A1   2069 BATHGATE AVENUE
# 2  42.0       NaN                        A1      2069 BATHGATE AVE
# 3  19.0       NaN                        A5   2186 BATHGATE AVENUE
# 4  28.0       NaN                        A1  540 EAST 182ND STREET
#
#   apartment_number  zip_code  residential_units  commercial_units  \
# ...

# %%
y = df_housing[['sale_price']]
y.head()
# Out:
#   sale_price
# 0          0
# 1        100
# 2        100
# 3     345752
# 4          0

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
